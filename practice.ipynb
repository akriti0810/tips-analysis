# %% [markdown]
# <a href="https://colab.research.google.com/github/akriti0810/Practice/blob/main/practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv"
df = pd.read_csv(url)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.groupby("sex")["total_bill"].mean()
# Out:
# sex
# Female    18.056897
# Male      20.744076
# Name: total_bill, dtype: float64

# %%
df.groupby("sex")["size"].mean()
# Out:
# sex
# Female    2.459770
# Male      2.630573
# Name: size, dtype: float64

# %%
df["bill_per_person"] = df["total_bill"] / df["size"]
df.groupby("sex")["bill_per_person"].mean()
# Out:
# sex
# Female    7.463918
# Male      8.123358
# Name: bill_per_person, dtype: float64

# %%
df["tip_pct"] = df["tip"] / df["total_bill"] * 100

# %%
import seaborn as sns
sns.boxplot(data=df, x="day", y="tip_pct")
# Out:
# <Axes: xlabel='day', ylabel='tip_pct'>

# %%
df[df["tip_pct"] > 40]
# Out:
#      total_bill   tip     sex smoker  day    time  size  bill_per_person  \
# 172        7.25  5.15    Male    Yes  Sun  Dinner     2            3.625
# 178        9.60  4.00  Female    Yes  Sun  Dinner     2            4.800
#
#        tip_pct
# 172  71.034483
# 178  41.666667
